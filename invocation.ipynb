# %% [markdown]
# # 导入ES数据

# %%
##功能拆解
#python连接Elasticsearch
#查询Elasticsearch打印结果
#导出所有结果数据
#将所有结果写入csv文件

# %%
from elasticsearch import Elasticsearch
from itertools import groupby
from matplotlib import pyplot as plt
from tqdm import tqdm_notebook as tqdm
from influxdb import DataFrameClient
import datetime
import time
import pickle
import pandas as pd
import numpy as np
import pandas as pd
np.set_printoptions(suppress=True)
pd.set_option('display.float_format', lambda x: '%.0f' % x) #避免科学技术法
# %matplotlib inline

# %%
def search_all(index, body):
    rsp = es.search(index=index, body=dict(**body, size=1000), scroll='1m',request_timeout=30)
    total = rsp['hits']['total']
    print(total)
    scroll_id = rsp['_scroll_id']
    scroll_size = total
    with tqdm(total=total) as pbar:
        rets = []
        while scroll_size > 0:
            _rsp = es.scroll(scroll_id=scroll_id, scroll='1m')
            scroll_id = _rsp['_scroll_id']
            scroll_size = len(_rsp['hits']['hits'])
            total -= scroll_size
            rets.extend(parse(_rsp['hits']['hits']))
            pbar.update(scroll_size)
        
    return rets

def parse(response):
    try:
        return list(map(
            lambda x: {
                'trace_id': x['_source']['traceId'],
                'timestamp': x['_source']['timestamp'],
                'latency': x['_source']['duration'],
                'http_status': x['_source']['tags']['http.status_code'],
                'request_parent_id': x['_source']['parentId'] if 'parentId' in x['_source'] else 'None',
                'request_id': x['_source']['id'],
                'source': x['_source']['localEndpoint']['serviceName'],
                'http_name': x['_source']['name'],
                'target': x['_source']['name'].split('.')[0] + '.default'
            },
            response,
        ))
    except KeyError:
        print('error:', response)

        
def dump_index(index):
    path = './event_title.txt'
    rets = search_all(
            index=index, 
            body={
                  "query": {
                    "range": {
                      "timestamp_millis": {
                        #"gte": 1565347635000,
                        #"lte": 1565350242000
                        "gte": 1567084200000,
                        "lte": 1567085100000
                      }
                    }
                  }
                },
        
    )
    with open(path, 'wb+') as f:
        pickle.dump(rets, f)
    return rets
def load_path(path):
    with open(path, 'rb') as f:
        return pickle.load(f)

# %%
es = Elasticsearch(host='192.168.115.84', port=9200)
requests_8_29 = dump_index("zipkin:span-2019-08-29")
data_8_29=load_path('./event_title.txt')
# Out:
# 40748
# HBox(children=(IntProgress(value=0, max=40748), HTML(value='')))

# %%
df = pd.DataFrame(data_8_29, columns=['trace_id',
                                      'timestamp',
                                      'latency',
                                      'http_status',
                                      'request_parent_id',
                                      'request_id',
                                      'source',
                                      'http_name',
                                      'target'] )
#df.to_csv('./event_title.csv')
df = df.drop(columns=['request_parent_id','request_id','http_name'])
df['source']=df['source'].apply(lambda x : ('.'+x).strip('default').strip('.'))
df['target']=df['target'].apply(lambda x : ('.'+x).strip('default').strip('.'))
df
# Out:
#                                trace_id         timestamp   latency  \
# 0      3e4c92af33630580eca1ec210550f66f  1567084433090689    399404
# 1      6d1bb6ea8133577502127e3401bbec41  1567084434031048     10673
# 2      6d1bb6ea8133577502127e3401bbec41  1567084434067402      4362
# 3      6d1bb6ea8133577502127e3401bbec41  1567084434078578      3502
# 4      6d1bb6ea8133577502127e3401bbec41  1567084429023205    430160
# 5      e5509cc13e65c4f7dd466bd545db0467  1567084429814289      6089
# 39735  d9a4b6b8632a824ad02c6fe85bfaa9c3  1567085099844072     13407
# 39736  654cbd061d2f7a6b969a73cab3bb7555  1567085099324783      8623
# 39737  654cbd061d2f7a6b969a73cab3bb7555  1567085099421596      9797
# 39738  654cbd061d2f7a6b969a73cab3bb7555  1567085099434050      6472
# 39739  654cbd061d2f7a6b969a73cab3bb7555  1567085099495054      5291
# 39740  654cbd061d2f7a6b969a73cab3bb7555  1567085098957343      4051
# 39741  654cbd061d2f7a6b969a73cab3bb7555  1567085099606564     34117
# 39742  a239ddbc13df82157b109d78de8e25b2  1567085099792112      4494
# 39743  47706d65464f503dc52adb19b824c9d1  1567085098897237      6124
# 39744  654cbd061d2f7a6b969a73cab3bb7555  1567085099242956      5502
# 39745  654cbd061d2f7a6b969a73cab3bb7555  1567085098825255      2681
# 39746  654cbd061d2f7a6b969a73cab3bb7555  1567085098778775      4605
# 39747  d0f5280545eebc9e161db124ff8eed09  1567085097863563    531783
#
#       http_status                   source                   target
# 0             200        ts-travel-service    ts-ticketinfo-service
# 1             200        ts-travel-service        ts-travel-service
# 2             200        ts-travel-service         ts-route-service
# 3             200        ts-travel-service         ts-route-service
# 4             200    ts-ticketinfo-service    ts-ticketinfo-service
# 5             200        ts-travel-service         ts-train-service
# 6             200          ts-seat-service        ts-travel-service
# 7             200          ts-seat-service        ts-travel-service
# 8             200    ts-ticketinfo-service         ts-basic-service
# 9             200         ts-price-service         ts-price-service
# 10            304     istio-ingressgateway          ts-ui-dashboard
# 11            200     istio-ingressgateway      ts-contacts-service
# 12            200     istio-ingressgateway         ts-order-service
# 13            200         ts-train-service         ts-train-service
# 14            200         ts-basic-service         ts-basic-service
# 15            200         ts-basic-service         ts-route-service
# 16            200       ts-travel2-service   ts-order-other-service
# 17            200          ts-seat-service        ts-travel-service
# 18            200    ts-ticketinfo-service    ts-ticketinfo-service
# 19            200         ts-basic-service         ts-basic-service
# 20            200         ts-basic-service       ts-station-service
# 21            200       ts-travel2-service         ts-route-service
# 22            200       ts-travel2-service       ts-travel2-service
# 23            200       ts-travel2-service    ts-ticketinfo-service
# 24            200        ts-travel-service    ts-ticketinfo-service
# 25            200        ts-travel-service         ts-route-service
# 26            200        ts-travel-service        ts-travel-service
# 27            200        ts-config-service        ts-config-service
# 28            200        ts-travel-service         ts-route-service
# 29            200    ts-ticketinfo-service         ts-basic-service
# ...           ...                      ...                      ...
# 39718         200       ts-travel2-service          ts-seat-service
# 39719         200       ts-travel2-service         ts-train-service
# 39720         200          ts-food-service      ts-food-map-service
# 39721         200   ts-order-other-service   ts-order-other-service
# 39722         200       ts-station-service       ts-station-service
# 39723         200       ts-station-service       ts-station-service
# 39724         200       ts-station-service       ts-station-service
# 39725         200    ts-ticketinfo-service         ts-basic-service
# 39726         200    ts-ticketinfo-service         ts-basic-service
# 39727         200      ts-preserve-service          ts-user-service
# 39728         200      ts-preserve-service  ts-notification-service
# 39729         200      ts-preserve-service      ts-preserve-service
# 39730         200         ts-order-service         ts-order-service
# 39731         200         ts-order-service         ts-order-service
# 39732         200     ts-assurance-service     ts-assurance-service
# 39733         200          ts-seat-service        ts-config-service
# 39734         200        ts-travel-service         ts-route-service
# 39735         200        ts-travel-service        ts-travel-service
# 39736         200    ts-ticketinfo-service    ts-ticketinfo-service
# 39737         200    ts-ticketinfo-service    ts-ticketinfo-service
# 39738         200    ts-ticketinfo-service         ts-basic-service
# 39739         200       ts-station-service       ts-station-service
# 39740         200        ts-travel-service         ts-route-service
# 39741         200        ts-travel-service        ts-travel-service
# 39742         200     istio-ingressgateway     ts-assurance-service
# 39743         200         ts-price-service         ts-price-service
# 39744         200       ts-travel2-service         ts-train-service
# 39745         200         ts-route-service         ts-route-service
# 39746         200         ts-basic-service       ts-station-service
# 39747         200  ts-admin-travel-service       ts-travel2-service
#
# [39748 rows x 6 columns]

# %% [markdown]
# # 获取influxdb的数据

# %%
#> SELECT * FROM "h2o_feet" WHERE time >= '2015-08-17T23:48:00Z' AND time <= '2015-08-18T00:30:00Z'
#print('数据库中的名称'+str(client.get_list_database()))
#print('数据库中的表'+str(client.query('show measurements;')))

# %%
def get_db(svc):
    client = DataFrameClient('192.168.115.31',34002,'root','','aiops_metric')#初始化
    query = 'select * from "{}" where time >= 1567055400000000000 and time<= 1567056300000000000'.format(svc)#time>now()-1h;
    result = dict(client.query(query,chunked=False))
    result = result[svc].reset_index().rename(columns={'index':'timestamp'})
    result['timestamp'] = result.apply(lambda x : x['timestamp'].timestamp(),axis=1)
    result['service'] = svc
    result['timestamp'] = result['timestamp']+28800
    return result
#因为容器数目不一致，需要转换名称
def dflist_2_dblist(df):
    db_list=[]
    df_list=list(set(df['target']))
    for i in df_list:
        db_list.append('metric.'+i)
    return db_list
#读取fluxdb所有需要的数据为一个大表
def all_db(df):
    db_list=dflist_2_dblist(df)
    df=get_db(db_list[0])
    for i in db_list[1:]:
        df = pd.concat((df, get_db(i)))
    df['service']=df['service'].apply(lambda x:(x+'.').strip('metric').strip('.'))
    df = df.fillna(0)
    #cpu使用率，service，timestamp，内存使用率，内存使用量，文件系统写入速率，文件系统读取速率，网络发送速率，网络接受速率
    df.columns = ['cpu_use', 'target', 'timestamp', 'mem_use_percent', 'mem_use_amount', 
                         'file_write_rate',  'file_read_rate', 'net_send_rate', 'file_recieve_rate']
    return df

# %%
db_data=all_db(df)
db_data
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#     cpu_use                     target  timestamp  mem_use_percent  \
# 0        21          ts-travel-service 1567084200                0
# 1        24          ts-travel-service 1567084260                0
# 2        29          ts-travel-service 1567084320                0
# 3        27          ts-travel-service 1567084380                0
# 4        21          ts-travel-service 1567084440                0
# 5        28          ts-travel-service 1567084500                0
# 6        27          ts-travel-service 1567084560                0
# 7        27          ts-travel-service 1567084620                0
# 8        26          ts-travel-service 1567084680                0
# 9        25          ts-travel-service 1567084740                0
# 10       27          ts-travel-service 1567084800                0
# 11       28          ts-travel-service 1567084860                0
# 12       28          ts-travel-service 1567084920                0
# 13       28          ts-travel-service 1567084980                0
# 14       28          ts-travel-service 1567085040                0
# 15       27          ts-travel-service 1567085100                0
# 0        22           ts-basic-service 1567084200                0
# 1        29           ts-basic-service 1567084260                0
# 2        34           ts-basic-service 1567084320                0
# 3        32           ts-basic-service 1567084380                0
# 4        30           ts-basic-service 1567084440                0
# 5        33           ts-basic-service 1567084500                0
# 6        34           ts-basic-service 1567084560                0
# 7        32           ts-basic-service 1567084620                0
# 8        31           ts-basic-service 1567084680                0
# 9        29           ts-basic-service 1567084740                0
# 10       34           ts-basic-service 1567084800                0
# 11       34           ts-basic-service 1567084860                0
# 12       36           ts-basic-service 1567084920                0
# 13       30           ts-basic-service 1567084980                0
# ..      ...                        ...        ...              ...
# 2         3          ts-cancel-service 1567084320                0
# 3         3          ts-cancel-service 1567084380                0
# 4         2          ts-cancel-service 1567084440                0
# 5         3          ts-cancel-service 1567084500                0
# 6         3          ts-cancel-service 1567084560                0
# 7         2          ts-cancel-service 1567084620                0
# 8         2          ts-cancel-service 1567084680                0
# 9         2          ts-cancel-service 1567084740                0
# 10        2          ts-cancel-service 1567084800                0
# 11        2          ts-cancel-service 1567084860                0
# 12        3          ts-cancel-service 1567084920                0
# 13        3          ts-cancel-service 1567084980                0
# 14        2          ts-cancel-service 1567085040                0
# 15        2          ts-cancel-service 1567085100                0
# 0         1  ts-preserve-other-service 1567084200                0
# 1         1  ts-preserve-other-service 1567084260                0
# 2         1  ts-preserve-other-service 1567084320                0
# 3         1  ts-preserve-other-service 1567084380                0
# 4         1  ts-preserve-other-service 1567084440                0
# 5         1  ts-preserve-other-service 1567084500                0
# 6         2  ts-preserve-other-service 1567084560                0
# 7         1  ts-preserve-other-service 1567084620                0
# 8         1  ts-preserve-other-service 1567084680                0
# 9         1  ts-preserve-other-service 1567084740                0
# 10        3  ts-preserve-other-service 1567084800                0
# 11        2  ts-preserve-other-service 1567084860                0
# 12        1  ts-preserve-other-service 1567084920                0
# 13        1  ts-preserve-other-service 1567084980                0
# 14        1  ts-preserve-other-service 1567085040                0
# 15        1  ts-preserve-other-service 1567085100                0
#
#     mem_use_amount  file_write_rate  file_read_rate  net_send_rate  \
# 0       1039515648                0               0         133302
# 1       1039568896                0               0         151717
# 2       1040400384                0               0         181574
# 3       1040429056                0               0         161577
# 4       1040379904                0               0         154591
# 5       1040924672                0               0         174548
# 6       1041010688                0               0         164718
# 7       1040584704                0               0         169133
# 8       1040723968                0               0         171663
# 9       1039548416                0               0         128738
# 10      1039613952                0               0         170925
# 11      1041608704                0               0         177721
# 12      1041551360                0               0         156417
# 13      1041563648                0               0         175566
# 14      1041752064                0               0         160435
# 15      1040998400                0               0         155677
# 0        958607360                0               0         138667
# 1        955633664                0               0         180330
# 2        959213568                0               0         189605
# 3        960167936                0               0         176754
# 4        960450560                0               0         169668
# 5        960110592                0               0         190354
# 6        959987712                0               0         184579
# 7        960786432                0               0         175429
# 8        960655360                0               0         176303
# 9        960966656                0               0         174405
# 10       959533056                0               0         190453
# 11       960520192                0               0         183878
# 12       960315392                0               0         187066
# 13       961761280                0               0         193153
# ..             ...              ...             ...            ...
# 2        787591168                0               0          20973
# 3        787976192                0               0          18744
# 4        788115456                0               0          11217
# 5        788078592                0               0          14374
# 6        788189184                0               0          13676
# 7        788254720                0               0          12212
# 8        788557824                0               0           8041
# 9        788680704                0               0          13788
# 10       788787200                0               0          10825
# 11       788926464                0               0          13375
# 12       789082112                0               0          15078
# 13       789331968                0               0          17277
# 14       789409792                0               0           8270
# 15       789237760                0               0          11954
# 0        721645568                0               0           5754
# 1        721657856                0               0           5433
# 2        721657856                0               0           7259
# 3        721600512                0               0           7779
# 4        721600512                0               0           8006
# 5        721620992                0               0           6949
# 6        721698816                0               0          12123
# 7        721625088                0               0           6989
# 8        721551360                0               0           4047
# 9        721809408                0               0           7232
# 10       722092032                0               0          10553
# 11       722092032                0               0           8285
# 12       722083840                0               0           5509
# 13       722132992                0               0           5207
# 14       722104320                0               0           3468
# 15       722108416                0               0           5861
#
#     file_recieve_rate
# 0               43417
# 1               49692
# 2               59484
# 3               52905
# 4               50885
# 5               57405
# 6               54519
# 7               55575
# 8               56244
# 9               42483
# 10              56516
# 11              63359
# 12              56886
# 13              57856
# 14              52408
# 15              51328
# 0               44083
# 1               57521
# 2               60543
# 3               56705
# 4               54348
# 5               60957
# 6               59269
# 7               56187
# 8               56175
# 9               55750
# 10              61103
# 11              58908
# 12              59938
# 13              61853
# ..                ...
# 2                5811
# 3                5113
# 4                2967
# 5                3973
# 6                3705
# 7                3222
# 8                2129
# 9                3707
# 10               2857
# 11               3647
# 12               4089
# 13               4723
# 14               2259
# 15               3261
# 0                1225
# 1                1149
# 2                1558
# 3                1646
# 4                1750
# 5                1492
# 6                2683
# 7                1516
# 8                 812
# 9                1552
# 10               2352
# 11               1841
# 12               1146
# 13               1067
# 14                707
# 15               1289
#
# [560 rows x 9 columns]

# %% [markdown]
# # 整合

# %%
time_start=1567084200


def time_to_little(data):
    n = (data - time_start * 1000000) // 60000000  
    return 1567084200 + n * 60

def es_time_to_little(df):
    df['timestamp'] = df['timestamp'].apply(time_to_little)#利用字典取分段函数
    df = df[~df['source'].isin(['istio-ingressgateway'])]
    return df

def zhenghe(df,db_data):
    df1 = df.copy()
    es_z = es_time_to_little(df1)
    result = pd.merge(es_z, db_data, on=['timestamp','target'])
    result['timestamp'] = df['timestamp']
    return result

# %%
zh=zhenghe(df,db_data)
zh
# Out:
#                                trace_id         timestamp  latency  \
# 0      3e4c92af33630580eca1ec210550f66f  1567084433090689   399404
# 1      6d1bb6ea8133577502127e3401bbec41  1567084434031048   430160
# 2      3e4c92af33630580eca1ec210550f66f  1567084434067402   897216
# 3      e5509cc13e65c4f7dd466bd545db0467  1567084434078578   293898
# 4      e5509cc13e65c4f7dd466bd545db0467  1567084429023205   199451
# 5      6d1bb6ea8133577502127e3401bbec41  1567084429814289   303742
# 6      e5509cc13e65c4f7dd466bd545db0467  1567084428913277   200645
# 7      e5509cc13e65c4f7dd466bd545db0467  1567084429792736  2204431
# 8      094ac42cc35dc46b5cdf8558894cb4ba  1567084429557669  2455034
# 9      89a7ff1bbd0281b4460d9e2e27e47838  1567084427654258  2787051
# 10     b30643a599a3129c86d096a55dd62999  1567084428301201   600001
# 11     c09fb3d2266171f464e8e6b13180cdc8  1567084428369629  1098085
# 12     c09fb3d2266171f464e8e6b13180cdc8  1567084429038264   108230
# 36830  4567acb25ef7f7cf34edeaeb3ce6e82c  1567084796723821    10743
# 36831  f5caba5df8c38508be64860f7bf99f40  1567084796365954   980902
# 36832  f50d32486402fb4ff24de549d8a6cb17  1567084796699576   460129
# 36833  f4a4ff1bbb99d74493a1893e195891a3  1567084796776723  2398117
# 36834  6b5530899e12c00856b7190efc79c7cf  1567084796808333  1331102
#
#       http_status                       source                       target  \
# 0             200            ts-travel-service        ts-ticketinfo-service
# 1             200        ts-ticketinfo-service        ts-ticketinfo-service
# 2             200        ts-ticketinfo-service        ts-ticketinfo-service
# 3             200           ts-travel2-service        ts-ticketinfo-service
# 4             200            ts-travel-service        ts-ticketinfo-service
# 5             200        ts-ticketinfo-service        ts-ticketinfo-service
# 6             200           ts-travel2-service        ts-ticketinfo-service
# 7             200            ts-travel-service        ts-ticketinfo-service
# 8             200        ts-ticketinfo-service        ts-ticketinfo-service
# 9             200        ts-ticketinfo-service        ts-ticketinfo-service
# 10            200            ts-travel-service        ts-ticketinfo-service
# 11            200        ts-ticketinfo-service        ts-ticketinfo-service
# 12            200            ts-travel-service        ts-ticketinfo-service
# 13            200        ts-ticketinfo-service        ts-ticketinfo-service
# 14            200            ts-travel-service        ts-ticketinfo-service
# 15            200            ts-travel-service        ts-ticketinfo-service
# 16            200        ts-ticketinfo-service        ts-ticketinfo-service
# 17            200        ts-ticketinfo-service        ts-ticketinfo-service
# 18            200        ts-ticketinfo-service        ts-ticketinfo-service
# 19            200        ts-ticketinfo-service        ts-ticketinfo-service
# 20            200        ts-ticketinfo-service        ts-ticketinfo-service
# 21            200        ts-ticketinfo-service        ts-ticketinfo-service
# 22            200        ts-ticketinfo-service        ts-ticketinfo-service
# 23            200        ts-ticketinfo-service        ts-ticketinfo-service
# 24            200            ts-travel-service        ts-ticketinfo-service
# 25            200            ts-travel-service        ts-ticketinfo-service
# 26            200        ts-ticketinfo-service        ts-ticketinfo-service
# 27            200        ts-ticketinfo-service        ts-ticketinfo-service
# 28            200        ts-ticketinfo-service        ts-ticketinfo-service
# 29            200        ts-ticketinfo-service        ts-ticketinfo-service
# ...           ...                          ...                          ...
# 36805         200       ts-travel-plan-service        ts-route-plan-service
# 36806         200           ts-consign-service           ts-consign-service
# 36807         200           ts-consign-service           ts-consign-service
# 36808         200           ts-consign-service           ts-consign-service
# 36809         200       ts-travel-plan-service       ts-travel-plan-service
# 36810         200       ts-travel-plan-service       ts-travel-plan-service
# 36811         200       ts-travel-plan-service       ts-travel-plan-service
# 36812         200        ts-route-plan-service        ts-route-plan-service
# 36813         200        ts-admin-user-service        ts-admin-user-service
# 36814         200       ts-admin-route-service       ts-admin-route-service
# 36815         200  ts-admin-basic-info-service  ts-admin-basic-info-service
# 36816         200       ts-travel-plan-service       ts-travel-plan-service
# 36817         200       ts-travel-plan-service       ts-travel-plan-service
# 36818         200       ts-admin-route-service       ts-admin-route-service
# 36819         200            ts-cancel-service    ts-inside-payment-service
# 36820         200    ts-inside-payment-service    ts-inside-payment-service
# 36821         200           ts-consign-service           ts-consign-service
# 36822         200            ts-cancel-service            ts-cancel-service
# 19                  0         119859              44876
# 20                  0         119859              44876
# 21                  0         119859              44876
# 22                  0         119859              44876
# 23                  0         119859              44876
# 24                  0         119859              44876
# 25                  0         119859              44876
# 26                  0         119859              44876
# 27                  0         119859              44876
# 28                  0         119859              44876
# 29                  0         119859              44876
# ...               ...            ...                ...
# 36805               0          10106               2671
# 36806               0           3008                687
# 36807               0           3008                687
# 36808               0           3008                687
# 36809               0          25606               5360
# 36810               0          25606               5360
# 36811               0          25606               5360
# 36812               0          10395               2713
# 36813               0           2569                649
# 36814               0           2030                312
# 36815               0           1968                297
# 36816               0          29676               6104
# 36817               0          29676               6104
# 36818               0           1982                316
# 36819               0          26667             600969
# 36820               0          26667             600969
# 36821               0           2483                459
# 36822               0          13375               3647
# 36823               0          13375               3647
# 36824               0          42514              22826
# 36825               0           2416                539
# 36826               0           4354               1416
# 36827               0          38627               7927
# 36828               0          38627               7927
# 36829               0           2445                534
# 36830               0          28930              17811
# 36831               0           7232               1552
# 36832               0           2882                646
# 36833               0          35257               7203
# 36834               0           3468                707
#
# [36835 rows x 13 columns]

# %% [markdown]
# # 转换为invocation

# %%
# 每个trace_id按照endtime降序进行排序，并转换为csv文件
#index需要咋csv中手动删除
def trans_csv(df):
    df['endtime']=df['timestamp']+df['latency']
    grouped = df.groupby('trace_id').apply(lambda x: x.sort_values('endtime', ascending=False))
    grouped['s_t']=grouped['source'].str.cat(grouped['target'],sep='->')
    grouped=grouped.drop(columns=['target','source','trace_id'])
    grouped.fillna(0)
    grouped.to_csv('grouped.csv') 
    #return grouped

#以traceid为单位进行整合
def trans(df):
    for i in df.columns[1:]:
        df[i]=str(list(df[i]))
    df=df.drop_duplicates(['trace_id'])
    return df

#输入csv文件名
def trans_last(zh):
    trans_csv(zh)
    df=pd.read_csv('grouped.csv').drop(columns='Unnamed: 1')
    df1 = df.groupby('trace_id').apply(trans).drop(columns='trace_id')
    df1.to_csv('grouped1.csv')
    df2 = pd.read_csv('grouped1.csv').drop(columns='Unnamed: 1')
    return df2

# %%
dfn = trans_last(zh)

# %%
dfn.head(10).to_dict(orient='records')
# Out:
# [{'trace_id': '00084bf4e31a5a323e2b69e8e2368ec6',
#   'timestamp': '[1567084542556010, 1567084517210059, 1567084467728282]',
#   'latency': '[12180, 5057, 6323]',
#   'http_status': '[200, 200, 200]',
#   'cpu_use': '[20.50201196070783, 30.90605216059944, 30.90605216059944]',
#   'mem_use_percent': '[0.4042396545410156, 0.40468597412109375, 0.40468597412109375]',
#   'mem_use_amount': '[999620608, 986808320, 986808320]',
#   'file_write_rate': '[0.0, 0.0, 0.0]',
#   'file_read_rate': '[0.0, 0.0, 0.0]',
#   'net_send_rate': '[58651.99764598183, 103372.21845062985, 103372.21845062985]',
#   'file_recieve_rate': '[43193.50901283812, 70098.86286490156, 70098.86286490156]',
#   'endtime': '[1567084542568190, 1567084517215116, 1567084467734605]',
#   's_t': "['ts-order-service->ts-order-service', 'ts-station-service->ts-station-service', 'ts-order-service->ts-station-service']"},
#  {'trace_id': '00340510346cd70a0ccc9d66eeff4443',
#   'timestamp': '[1567084546041882]',
#   'latency': '[2760]',
#   'http_status': '[200]',
#   'cpu_use': '[2.4097605894725]',
#   'mem_use_percent': '[0.3533897399902344]',
#   'mem_use_amount': '[870539264]',
#   'file_write_rate': '[0.0]',
#   'file_read_rate': '[0.0]',
#   'net_send_rate': '[9221.865115627192]',
#   'file_recieve_rate': '[3221.626664330764]',
#   'endtime': '[1567084546044642]',
#   's_t': "['ts-verification-code-service->ts-verification-code-service']"},
#  {'trace_id': '004afa4242cb52f3909555143b01f54e',
#   'timestamp': '[1567084784590076, 1567084731211026, 1567084725769991]',
#   'latency': '[12119, 4217, 6074]',
#   'http_status': '[200, 200, 200]',
#   'cpu_use': '[2.0880661353620305, 19.31715163305614, 19.31715163305614]',
#   'mem_use_percent': '[0.314300537109375, 0.404205322265625, 0.404205322265625]',
#   'mem_use_amount': '[788787200, 999714816, 999714816]',
#   'file_write_rate': '[0.0, 0.0, 0.0]',
#   'file_read_rate': '[0.0, 0.0, 0.0]',
#   'net_send_rate': '[10824.864742547983, 54564.24977047428, 54564.24977047428]',
#   'file_recieve_rate': '[2856.657958075333, 41703.96411263613, 41703.96411263613]',
#   'endtime': '[1567084784602195, 1567084731215243, 1567084725776065]',
#   's_t': "['ts-cancel-service->ts-cancel-service', 'ts-order-service->ts-order-service', 'ts-cancel-service->ts-order-service']"},
#  {'trace_id': '004e5fc45f895d1c7367f852406779cb',
#   'timestamp': '[1567084986791657, 1567084856337990, 1567084821004219]',
#   'latency': '[26071, 21398, 19697]',
#   'http_status': '[200, 200, 200]',
#   'cpu_use': '[20.920869005892907, 33.1264239155664, 33.1264239155664]',
#   'mem_use_percent': '[0.404205322265625, 0.4047203063964844, 0.4047203063964844]',
#   'mem_use_amount': '[999714816, 986877952, 986877952]',
#   'file_write_rate': '[0.0, 0.0, 0.0]',
#   'file_read_rate': '[0.0, 0.0, 0.0]',
#   'net_send_rate': '[62156.15729003723, 105630.93745647023, 105630.93745647023]',
#   'file_recieve_rate': '[51065.59145584983, 72174.5600594326, 72174.5600594326]',
#   'endtime': '[1567084986817728, 1567084856359388, 1567084821023916]',
#   's_t': "['ts-order-service->ts-order-service', 'ts-order-service->ts-station-service', 'ts-station-service->ts-station-service']"},
#  {'trace_id': '00608ee82a97aa30fb1783124195ac30',
#   'timestamp': '[1567084955106714]',
#   'latency': '[660]',
#   'http_status': '[304]',
#   'cpu_use': '[0.11251578527713244]',
#   'mem_use_percent': '[0.0087890625]',
#   'mem_use_amount': '[120295424]',
#   'file_write_rate': '[0.0]',
#   'file_read_rate': '[0.0]',
#   'net_send_rate': '[8707.434702503522]',
#   'file_recieve_rate': '[4285.607456378021]',
#   'endtime': '[1567084955107374]',
#   's_t': "['ts-ui-dashboard->ts-ui-dashboard']"},
#  {'trace_id': '006daac022f98783f09380c45ab1051f',
#   'timestamp': '[1567084966507541]',
#   'latency': '[681]',
#   'http_status': '[304]',
#   'cpu_use': '[0.17924042750147265]',
#   'mem_use_percent': '[0.0087890625]',
#   'mem_use_amount': '[120229888]',
#   'file_write_rate': '[0.0]',
#   'file_read_rate': '[0.0]',
#   'net_send_rate': '[11661.588430084319]',
#   'file_recieve_rate': '[6172.744681076163]',
#   'endtime': '[1567084966508222]',
#   's_t': "['ts-ui-dashboard->ts-ui-dashboard']"},
#  {'trace_id': '009f42de62e0494ce0d62ce7f74ef7af',
#   'timestamp': '[1567084756448550, 1567084749027221]',
#   'latency': '[3483, 4233]',
#   'http_status': '[200, 200]',
#   'cpu_use': '[17.81526566976986, 17.81526566976986]',
#   'mem_use_percent': '[0.4043388366699219, 0.4043388366699219]',
#   'mem_use_amount': '[1000001536, 1000001536]',
#   'file_write_rate': '[0.0, 0.0]',
#   'file_read_rate': '[0.0, 0.0]',
#   'net_send_rate': '[50851.78475312775, 50851.78475312775]',
#   'file_recieve_rate': '[36147.165005973264, 36147.165005973264]',
#   'endtime': '[1567084756452033, 1567084749031454]',
#   's_t': "['ts-order-service->ts-order-service', 'ts-admin-order-service->ts-order-service']"},
#  {'trace_id': '00a54e81141f10f43300c9c30cfa7c8b',
#   'timestamp': '[1567084909314861, 1567084897616704, 1567084693234030]',
#   'latency': '[184455, 185137, 190134]',
#   'http_status': '[200, 200, 200]',
#   'cpu_use': '[23.802529401137253, 23.802529401137253, 6.852002956214191]',
#   'mem_use_percent': '[0.4040260314941406, 0.4040260314941406, 0.31613922119140625]',
#   'mem_use_amount': '[999141376, 999141376, 792469504]',
#   'file_write_rate': '[0.0, 0.0, 0.0]',
#   'file_read_rate': '[0.0, 0.0, 0.0]',
#   'net_send_rate': '[94760.08206998746, 94760.08206998746, 60867.266796849864]',
#   'file_recieve_rate': '[98727.92659295566, 98727.92659295566, 43250.53110448274]',
#   'endtime': '[1567084909499316, 1567084897801841, 1567084693424164]',
#   's_t': "['ts-order-service->ts-order-service', 'ts-admin-order-service->ts-order-service', 'ts-admin-order-service->ts-admin-order-service']"},
#  {'trace_id': '00a6e698398dd1bea1a276a47b9a18f7',
#   'timestamp': '[1567084986917020]',
#   'latency': '[84466]',
#   'http_status': '[200]',
#   'cpu_use': '[27.37450003573173]',
#   'mem_use_percent': '[0.4046058654785156]',
#   'mem_use_amount': '[986628096]',
#   'file_write_rate': '[0.0]',
#   'file_read_rate': '[0.0]',
#   'net_send_rate': '[81575.862694418]',
#   'file_recieve_rate': '[56425.2482655421]',
#   'endtime': '[1567084987001486]',
#   's_t': "['ts-order-other-service->ts-station-service']"},
#  {'trace_id': '00be980203f70d15bc09e3f432c0a803',
#   'timestamp': '[1567084236493874, 1567084231395459]',
#   'latency': '[6253, 6896]',
#   'http_status': '[200, 200]',
#   'cpu_use': '[21.238039055161885, 21.238039055161885]',
#   'mem_use_percent': '[0.4041023254394531, 0.4041023254394531]',
#   'mem_use_amount': '[999317504, 999317504]',
#   'file_write_rate': '[0.0, 0.0]',
#   'file_read_rate': '[0.0, 0.0]',
#   'net_send_rate': '[65297.4816317197, 65297.4816317197]',
#   'file_recieve_rate': '[54640.538471480686, 54640.538471480686]',
#   'endtime': '[1567084236500127, 1567084231402355]',
#   's_t': "['ts-order-service->ts-order-service', 'ts-admin-order-service->ts-order-service']"}]
